# %%
#Imports
import os
from python_files.data_prep.I_data_prep import load_train_data

# %%
#Constants and paths
raw_data_path="artifacts/raw_data.csv.dvc"

# %% [markdown]
# # Data prep

# %%
os.makedirs("artifacts", exist_ok=True)
print("Created artifacts directory")
# Out:
# Created artifacts directory

# %%
df, min_date, max_date = load_train_data(raw_data_path)
# Out:
# Loading training data
# Total rows: md5: 23cfa41cb69f086c19792422e70d0800    12
# dtype: int64
#                md5: 23cfa41cb69f086c19792422e70d0800
# 0                                       frozen: true
# 1                                              deps:
# 2  - checksum: '"179c6d37c5ff4a70c91a9247d81e5b24...
# 3                                      size: 1358284
# 4                                          hash: md5
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\DSiP-100_leGIT\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_part'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df, min_datae, max_data = load_train_data(raw_data_path)
#
# File ~\Documents\GitHub\ITU_DSiP-100_LeGIT_project\notebooks\python_files\data_prep\I_data_prep.py:26, in load_train_data(raw_data_path)
#      23 min_date = pd.to_datetime("2024-01-01").date()
#      25 # Time limit data
# ---> 26 data["date_part"] = pd.to_datetime(data["date_part"]).dt.date
#      27 data = data[(data["date_part"] >= min_date) & (data["date_part"] <= max_date)]
#      29 min_date = data["date_part"].min()
#
# File ~\anaconda3\envs\DSiP-100_leGIT\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\DSiP-100_leGIT\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'date_part'

# %% [markdown]
# # Data cleaning

# %% [markdown]
# # Training two models

# %% [markdown]
# # Testing and comparing

# %% [markdown]
# # Best model and deployment
